# %% [markdown]
# # Descriptive Statistics

# %%
#imports
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter, defaultdict

# %%
#directory locations
current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)
processed_folder = parent_directory + '/data/wine-com/processed/'

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv(processed_folder + '1676752918.122732.txt', sep = '|')

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.wine.com/product/domaine-du-terme-...
# 1  https://www.wine.com/product/viticcio-chianti-...
# 2  https://www.wine.com/product/bodegas-urbina-cr...
# 3  https://www.wine.com/product/sanford-sanford-a...
# 4  https://www.wine.com/product/san-simeon-estate...
#
#                                                 name           variety  \
# 0                     Domaine du Terme Gigondas 2019  Rhone Red Blends
# 1             Viticcio Chianti Classico Riserva 2017        Sangiovese
# 2                        Bodegas Urbina Crianza 2012       Tempranillo
# 3  Sanford Sanford & Benedict Vineyard Pinot Noir...        Pinot Noir
# 4        San Simeon Estate Reserve Petite Sirah 2019      Petite Sirah
#
#                                               origin      type  \
# 0                       from Gigondas, Rhone, France  Red Wine
# 1     from Chianti Classico, Chianti, Tuscany, Italy  Red Wine
# 2                                  from Rioja, Spain  Red Wine
# 3   from Sta. Rita Hills, Santa Barbara, Central ...  Red Wine
# 4        from Paso Robles, Central Coast, California  Red Wine
#
#                                          description  \
# 0                                                NaN
# 1  intense ruby red violet nuance complexnose sou...
# 2  medium crimson color emit aromatic array cedar...
# 3  2017 pinot noir sanford benedict bright beauti...
# 4  aromas blackberry ripe plum thyme greet nose a...
#
#                                              reviews
# 0  spectacular gigondas wine red cherry flavor so...
# 1  supple vibrant concentrate feature black cherr...
# 2  dark amber rim red aromas red currant cherry p...
# 3  lastly 2017 pinot noir sanford benedict come s...
# 4  cassis cola cream black cherry sauce aroma ric...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13042 entries, 0 to 13041
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   url          13042 non-null  object
#  1   name         13042 non-null  object
#  2   variety      13042 non-null  object
#  3   origin       13039 non-null  object
#  4   type         13042 non-null  object
#  5   description  11723 non-null  object
#  6   reviews      6643 non-null   object
# dtypes: object(7)
# memory usage: 713.4+ KB

# %% [markdown]
# ### Basic Descriptive Statistics

# %%
df.describe()
# Out:
#                                                       url  \
# count                                               13042
# unique                                              13042
# top     https://www.wine.com/product/domaine-du-terme-...
# freq                                                    1
#
#                                   name     variety  \
# count                            13042       13042
# unique                           13042         127
# top     Domaine du Terme Gigondas 2019  Pinot Noir
# freq                                 1        1662
#
#                                origin      type                description  \
# count                           13039     13042                      11723
# unique                            442         8                      11402
# top      from Napa Valley, California  Red Wine  barrel sample wine 14 abv
# freq                              584      7849                          6
#
#                                                   reviews
# count                                                6643
# unique                                               6575
# top     fist late summer cherry raspberry bilberry fru...
# freq                                                    3

# %% [markdown]
# Of note, this dataset contains 13,042 unqiue products across 127 vartietals and 8 distinct wine types. Descriptions provided by wine makers siginficantly outnumber the quantity of professional reviews.
#
# To ensure that sufficient coverage is present across wine types, the above statistics will be recomputed for each unique wine type.

# %%
df.groupby('type').describe()
# Out:
#                         url         \
#                       count unique
# type
# Boutique                 12     12
# Collectible              13     13
# Green Wine               10     10
# Pink and Rosé           415    415
# Red Wine               7849   7849
# Screw Cap                37     37
# Sparkling & Champagne   906    906
# White Wine             3800   3800
#
#                                                                                \
#                                                                      top freq
# type
# Boutique               https://www.wine.com/product/chambers-rosewood...    1
# Collectible            https://www.wine.com/product/alvear-pedro-xime...    1
# Green Wine             https://www.wine.com/product/chateau-guiraud-s...    1
# Pink and Rosé          https://www.wine.com/product/chateau-de-campug...    1
# Red Wine               https://www.wine.com/product/domaine-du-terme-...    1
# Screw Cap                https://www.wine.com/product/lillet-rose/147705    1
# Sparkling & Champagne  https://www.wine.com/product/nicolas-feuillatt...    1
# White Wine             https://www.wine.com/product/vina-esmeralda-bl...    1
#
#                        name         \
#                       count unique
# type
# Boutique                 12     12
# Collectible              13     13
# Green Wine               10     10
# Pink and Rosé           415    415
# Red Wine               7849   7849
# Screw Cap                37     37
# Sparkling & Champagne   906    906
# White Wine             3800   3800
#
#                                                                                \
#                                                                      top freq
# type
# Boutique               Chambers Rosewood Rutherglen Grand Muscat (375...    1
# Collectible                Alvear Pedro Ximenez 1927 (375ML half-bottle)    1
# Green Wine             Chateau Guiraud Sauternes (375ML half-bottle) ...    1
# Pink and Rosé                    Chateau de Campuget Tradition Rose 2020    1
# Red Wine                                  Domaine du Terme Gigondas 2019    1
# Screw Cap                                                    Lillet Rose    1
# Sparkling & Champagne          Nicolas Feuillatte Reserve Exclusive Brut    1
# White Wine                                    Vina Esmeralda Blanco 2020    1
#
#                       variety         ...  \
#                         count unique  ...
# type                                  ...
# Boutique                   12      4  ...
# Collectible                13      3  ...
# Green Wine                 10      1  ...
# Pink and Rosé             415      2  ...
# Red Wine                 7849     61  ...
# Screw Cap                  37      4  ...
# Sparkling & Champagne     906      4  ...
# White Wine               3800     55  ...
#
#                                                                   origin       \
#                                                                      top freq
# type
# Boutique                                            from Douro, Portugal    3
# Collectible                                         from Douro, Portugal    6
# Green Wine                              from Sauternes, Bordeaux, France    3
# Pink and Rosé           from Cotes de Provence, Provence, South of Fr...   52
# Red Wine                                    from Napa Valley, California  478
# Screw Cap                                              from Jerez, Spain   13
# Sparkling & Champagne                             from Champagne, France  316
# White Wine                                               from California  170
#
#                       description         \
#                             count unique
# type
# Boutique                       11     11
# Collectible                    13     12
# Green Wine                      7      7
# Pink and Rosé                 400    392
# Red Wine                     6980   6778
# Screw Cap                      36     36
# Sparkling & Champagne         829    800
# White Wine                   3447   3373
#
#                                                                                \
#                                                                      top freq
# type
# Boutique               produce muscat petit grains brown muscat commo...    1
# Collectible                                           blend 100 semillon    2
# Green Wine             sweet intensity vibrant acidity unique combina...    1
# Pink and Rosé          pibarnon craft fine mourvèdre base wine world ...    3
# Red Wine                                       barrel sample wine 14 abv    6
# Screw Cap              lillet rose wine aperitif france wine enthusia...    1
# Sparkling & Champagne  compose 20 chardonnay grape variety elegance d...    3
# White Wine             brilliant luminous tint green color bouquet re...    2
#
#                       reviews         \
#                         count unique
# type
# Boutique                    7      7
# Collectible                10     10
# Green Wine                  5      4
# Pink and Rosé             137    130
# Red Wine                 4386   4342
# Screw Cap                  14     14
# Sparkling & Champagne     518    511
# White Wine               1566   1557
#
#
#                                                                      top freq
# type
# Boutique               beautiful fortify compose solera wine go stagg...    1
# Collectible            nv pedro ximenez solera 1927 non vintage 1927 ...    1
# Green Wine             pretty note quince honey orange white flower a...    2
# Pink and Rosé          pale rise color pretty aroma lavender rosehip ...    3
# Red Wine               fist late summer cherry raspberry bilberry fru...    3
# Screw Cap              juicy peach nectar wild strawberry meet vibran...    1
# Sparkling & Champagne  commentary decoy brut bright active palate tas...    2
# White Wine             commentary 2021 rombauer vineyards chardonnay ...    2
#
# [8 rows x 24 columns]

# %% [markdown]
# Interestingly, there exists labels that don't relate to the wines family. Given the relative size of these record groups, it may be worth relabeling or dropping these groups.
#
# Another aspect worth noting is that unless the text bodies of 'description' and 'review' proven to diverge significantly, predictive models would likely benefit from combining these fields into a single corpus.

# %% [markdown]
# ### 'Description' Analysis

# %%
#lifted from homwork
def descriptive_stats(tokens, num_tokens = 10, verbose=True):
    tokens_str = tokens.astype(str)
    joined_series_tokens = ' '.join(tokens_str)
    tokens = joined_series_tokens.split()
    
    num_tokens = len(tokens)
    num_unique_tokens = len(set(tokens))
    lexical_diversity = num_unique_tokens/num_tokens #defined as unique tokens to the total number of words
    num_characters = sum(len(i) for i in tokens)
    
    if verbose :        
        print(f"There are {num_tokens} tokens in the data.")
        print(f"There are {num_unique_tokens} unique tokens in the data.")
        print(f"There are {num_characters} characters in the data.")
        print(f"The lexical diversity is {lexical_diversity:.3f} in the data.")
    
        # find five most common tokens
        counter = Counter(tokens)
        n_most_common_tokens = counter.most_common(10)
        print(f"The {num_tokens} most common tokens were:\n{n_most_common_tokens}")
        
    return([num_tokens, num_unique_tokens,
            lexical_diversity,
            num_characters])

# %%
unique_wines = df['type'].unique()

for wine_types in unique_wines:
    tmp = df[df['type'] == wine_types]
    print(f'{wine_types} Outputs\n')
    descriptive_stats(tmp['description'])
    print('\n')
# Out:
# Red Wine Outputs
#
# There are 223343 tokens in the data.
# There are 11328 unique tokens in the data.
# There are 1303326 characters in the data.
# The lexical diversity is 0.051 in the data.
# The 223343 most common tokens were:
# [('wine', 4797), ('fruit', 4356), ('red', 4331), ('tannin', 3141), ('cherry', 2874), ('note', 2840), ('palate', 2814), ('finish', 2621), ('black', 2573), ('aroma', 2246)]
#
#
# White Wine Outputs
#
# There are 105235 tokens in the data.
# There are 7629 unique tokens in the data.
# There are 629911 characters in the data.
# The lexical diversity is 0.072 in the data.
# The 105235 most common tokens were:
# [('wine', 2368), ('fruit', 1776), ('palate', 1487), ('note', 1409), ('white', 1356), ('finish', 1345), ('fresh', 1263), ('aroma', 1163), ('acidity', 1126), ('flavor', 1115)]
#
#
# Sparkling & Champagne Outputs
#
# There are 28284 tokens in the data.
# There are 3720 unique tokens in the data.
# There are 168286 characters in the data.
# The lexical diversity is 0.132 in the data.
# The 28284 most common tokens were:
# [('wine', 547), ('fruit', 490), ('note', 363), ('fresh', 362), ('palate', 357), ('pinot', 339), ('aroma', 307), ('fine', 289), ('blend', 268), ('finish', 262)]
#
#
# Pink and Rosé Outputs
#
# There are 13030 tokens in the data.
# There are 2312 unique tokens in the data.
# There are 77062 characters in the data.
# The lexical diversity is 0.177 in the data.
# The 13030 most common tokens were:
# [('wine', 241), ('rosé', 227), ('fruit', 212), ('fresh', 202), ('strawberry', 184), ('note', 168), ('palate', 157), ('finish', 157), ('red', 150), ('color', 149)]
#
#
# Collectible Outputs
#
# There are 403 tokens in the data.
# There are 273 unique tokens in the data.
# There are 2347 characters in the data.
# The lexical diversity is 0.677 in the data.
# The 403 most common tokens were:
# [('wine', 8), ('good', 8), ('palate', 6), ('fruit', 6), ('year', 5), ('aroma', 5), ('color', 5), ('long', 5), ('old', 4), ('rich', 4)]
#
#
# Green Wine Outputs
#
# There are 204 tokens in the data.
# There are 148 unique tokens in the data.
# There are 1214 characters in the data.
# The lexical diversity is 0.725 in the data.
# The 204 most common tokens were:
# [('wine', 10), ('sweet', 5), ('dessert', 4), ('balance', 4), ('aszu', 4), ('nan', 3), ('dry', 3), ('note', 3), ('honey', 3), ('fruity', 3)]
#
#
# Screw Cap Outputs
#
# There are 1185 tokens in the data.
# There are 550 unique tokens in the data.
# There are 7087 characters in the data.
# The lexical diversity is 0.464 in the data.
# The 1185 most common tokens were:
# [('vermouth', 24), ('wine', 18), ('color', 17), ('finish', 17), ('note', 17), ('dry', 16), ('sweet', 16), ('flavor', 16), ('orange', 15), ('aroma', 13)]
#
#
# Boutique Outputs
#
# There are 412 tokens in the data.
# There are 302 unique tokens in the data.
# There are 2372 characters in the data.
# The lexical diversity is 0.733 in the data.
# The 412 most common tokens were:
# [('wine', 13), ('fruit', 5), ('spice', 5), ('age', 5), ('sweet', 5), ('dry', 4), ('finish', 4), ('balanced', 4), ('black', 4), ('blend', 4)]

# %% [markdown]
# ### 'Review' Analysis

# %%
for wine_types in unique_wines:
    tmp = df[df['type'] == wine_types]
    print(f'{wine_types} Outputs\n')
    descriptive_stats(tmp['reviews'])
    print('\n')
# Out:
# Red Wine Outputs
#
# There are 299645 tokens in the data.
# There are 14152 unique tokens in the data.
# There are 1734928 characters in the data.
# The lexical diversity is 0.047 in the data.
# The 299645 most common tokens were:
# [('fruit', 4995), ('tannin', 4718), ('wine', 4145), ('finish', 3532), ('nan', 3463), ('black', 3256), ('bodied', 3109), ('red', 3001), ('cherry', 2939), ('palate', 2861)]
#
#
# White Wine Outputs
#
# There are 72711 tokens in the data.
# There are 6580 unique tokens in the data.
# There are 420027 characters in the data.
# The lexical diversity is 0.090 in the data.
# The 72711 most common tokens were:
# [('nan', 2234), ('fruit', 971), ('finish', 965), ('white', 910), ('wine', 894), ('palate', 830), ('note', 830), ('flavor', 812), ('lemon', 727), ('apple', 685)]
#
#
# Sparkling & Champagne Outputs
#
# There are 33529 tokens in the data.
# There are 3856 unique tokens in the data.
# There are 193872 characters in the data.
# The lexical diversity is 0.115 in the data.
# The 33529 most common tokens were:
# [('wine', 579), ('fruit', 452), ('note', 419), ('flavor', 395), ('nan', 388), ('pinot', 366), ('finish', 351), ('aroma', 319), ('apple', 317), ('palate', 315)]
#
#
# Pink and Rosé Outputs
#
# There are 5391 tokens in the data.
# There are 1269 unique tokens in the data.
# There are 30371 characters in the data.
# The lexical diversity is 0.235 in the data.
# The 5391 most common tokens were:
# [('nan', 278), ('rosé', 83), ('note', 77), ('wine', 76), ('fresh', 75), ('taste', 70), ('aroma', 70), ('fruit', 69), ('flavor', 69), ('red', 68)]
#
#
# Collectible Outputs
#
# There are 1199 tokens in the data.
# There are 571 unique tokens in the data.
# There are 6891 characters in the data.
# The lexical diversity is 0.476 in the data.
# The 1199 most common tokens were:
# [('wine', 15), ('finish', 14), ('dry', 13), ('barrel', 13), ('palate', 12), ('sample', 12), ('orange', 10), ('note', 9), ('style', 9), ('come', 9)]
#
#
# Green Wine Outputs
#
# There are 507 tokens in the data.
# There are 253 unique tokens in the data.
# There are 3131 characters in the data.
# The lexical diversity is 0.499 in the data.
# The 507 most common tokens were:
# [('apricot', 10), ('finish', 9), ('orange', 8), ('note', 7), ('honey', 7), ('lemon', 7), ('wine', 7), ('quince', 6), ('glass', 6), ('flavor', 6)]
#
#
# Screw Cap Outputs
#
# There are 609 tokens in the data.
# There are 369 unique tokens in the data.
# There are 3418 characters in the data.
# The lexical diversity is 0.606 in the data.
# The 609 most common tokens were:
# [('nan', 23), ('finish', 11), ('wine', 11), ('dry', 9), ('sweet', 9), ('flavor', 9), ('aroma', 8), ('acidity', 7), ('fresh', 7), ('note', 6)]
#
#
# Boutique Outputs
#
# There are 695 tokens in the data.
# There are 445 unique tokens in the data.
# There are 3997 characters in the data.
# The lexical diversity is 0.640 in the data.
# The 695 most common tokens were:
# [('wine', 11), ('note', 9), ('finish', 8), ('port', 8), ('dark', 7), ('year', 6), ('dry', 6), ('palate', 6), ('long', 6), ('fruit', 6)]

# %% [markdown]
# Based on the top 10 most common terms, joining the fields 'description' and 'reviews' is a reasonable proposal.

# %% [markdown]
# ### Description Lengths

# %%
df['description_length'] = df['description'].str.len()

# %%
fig = plt.figure(figsize=(10, 10))
df.groupby('type')['description_length'].plot(kind="hist",density=True,alpha=0.5,legend=True)
plt.show()

# %% [markdown]
# ### Review Lengths

# %%
df['review_length'] = df['reviews'].str.len()

# %%
fig = plt.figure(figsize=(10, 10))
df.groupby('type')['review_length'].plot(kind="hist", 
                                         density=True, 
                                         alpha=0.5,
                                         legend=True)
plt.show()

# %% [markdown]
# Interestingly, the distrbution of description and review lengths appear to follow different distribution types.

# %% [markdown]
# ### Unique Tokens
#
# Given that there are multiple labels in the set, we will modify a function from prior homework to perform OvR comparisons for terms unique to each wine type.

# %%
#modified from homework to be generally useful
def unique_tokens(df, comparison_column, split_column, n_total_corpora, n_top_terms):
    unique_splits = df[split_column].unique()
    for split in unique_splits:
        #perform split
        corpus_1 = df[df[split_column] == split]
        corpus_2 = df[df[split_column] != split]
        #preprocess
        corpus_1_str = corpus_1[comparison_column].astype(str)
        corpus_2_str = corpus_2[comparison_column].astype(str)
        corpus_1_joined = ' '.join(corpus_1_str)
        corpus_2_joined = ' '.join(corpus_2_str)
        corpus_1_tokens = corpus_1_joined.split()
        corpus_2_tokens = corpus_2_joined.split()
        #generate token counts for each corpora
        corpus_1_counts = Counter(corpus_1_tokens)
        corpus_2_counts = Counter(corpus_2_tokens)
        #write to dataframe
        corpus_1_df = pd.DataFrame(data = corpus_1_counts.values(), 
                               index = corpus_1_counts.keys(),
                               columns = ['1_word_counts'])
        corpus_2_df = pd.DataFrame(data = corpus_2_counts.values(), 
                               index = corpus_2_counts.keys(),
                               columns = ['2_word_counts'])
        #join dataframes
        corpus_df = corpus_1_df.merge(corpus_2_df, 
                                      how = 'outer',
                                      left_index = True, 
                                      right_index= True)
        #impute null values with 0
        corpus_df = corpus_df.fillna(0)
        #filtering corpora to required  relevance
        corpus_df = corpus_df[corpus_df['1_word_counts'] >= n_total_corpora]
        corpus_df = corpus_df[corpus_df['2_word_counts'] >= n_total_corpora]
        #calculate term concentrations
        corpus_df['1_concentrations'] = corpus_df['1_word_counts']/len(corpus_1)
        corpus_df['2_concentrations'] = corpus_df['2_word_counts']/len(corpus_2)
        #generate term ratio
        corpus_df['term_ratio'] = corpus_df['1_concentrations']/corpus_df['2_concentrations']
        #sort ratios
        corpus_df = corpus_df.sort_values(by = ['term_ratio'], ascending = False)
        #generate outputs
        corpus_1_top_n = corpus_df['term_ratio'].head(n_top_terms).to_dict()
        #print outputs
        print(f'Unique tokens observed for the label {split}:\n')
        print(corpus_1_top_n)
        print(f'\n')

# %% [markdown]
# ### Description Unique Terms

# %%
unique_tokens(df, 
              comparison_column = 'description', 
              split_column = 'type',
              n_total_corpora = 5,
              n_top_terms = 10)
# Out:
# Unique tokens observed for the label Red Wine:
#
# {'tannin': 56.16557454383929, 'blackberry': 53.54654096063192, 'merlot': 53.47035522764915, 'verdot': 51.73813224614601, 'black': 50.06853252193985, 'cabernet': 48.069602541066075, 'ruby': 45.21021786214805, 'purple': 43.66645432539177, 'dark': 37.96289446052869, 'cassis': 33.49415530640846}
#
#
# Unique tokens observed for the label White Wine:
#
# {'riesling': 60.58153110047847, 'grigio': 48.642105263157895, 'chablis': 40.85936842105263, 'pineapple': 39.12517162471396, 'lime': 31.997384868421054, 'tropical': 27.5014979757085, 'lemongrass': 23.626165413533833, 'roussanne': 22.375368421052634, 'curd': 21.888947368421054, 'guava': 20.499172932330826}
#
#
# Unique tokens observed for the label Sparkling & Champagne:
#
# {'champagne': 263.43782192788814, 'bubble': 234.41501103752756, 'sparkling': 64.4641280353201, 'sparkle': 59.72001471670346, 'macabeo': 44.6504782928624, 'effervescence': 33.4878587196468, 'grande': 29.469315673289184, 'yeasty': 28.46467991169978, 'noirs': 25.450772626931567, 'method': 21.63830871115639}
#
#
# Unique tokens observed for the label Pink and Rosé:
#
# {'watermelon': 91.27951807228915, 'rosé': 69.0681686746988, 'provence': 51.244641724793915, 'provençal': 40.56867469879518, 'cinsault': 30.837675024422012, 'hondarrabi': 30.426506024096387, 'pink': 22.664642242439143, 'sipper': 19.362322015334065, 'bluish': 19.01656626506024, 'vermentino': 13.945481927710842}
#
#
# Unique tokens observed for the label Collectible:
#
# {'good': 7.335632345696389, 'year': 5.35379684418146, 'long': 2.5194338090265695, 'color': 1.9024881724198355, 'aroma': 1.2978901440439903, 'palate': 1.2450071667462974, 'wine': 1.0029830064856335, 'fruit': 0.8777382302415144}
#
#
# Unique tokens observed for the label Green Wine:
#
# {'sweet': 7.013993541442411, 'wine': 1.6306306306306306}
#
#
# Unique tokens observed for the label Screw Cap:
#
# {'ice': 205.0337837837838, 'proof': 175.74324324324326, 'cocktail': 85.20884520884522, 'slice': 84.84156570363469, 'salt': 37.27886977886978, 'bitter': 27.03742203742204, 'dessert': 19.171990171990174, 'try': 15.976658476658477, 'sea': 13.347588094423537, 'base': 13.157248157248159}
#
#
# Unique tokens observed for the label Boutique:
#
# {'sweet': 5.844097595981342, 'age': 5.359493254359987, 'spice': 2.2565114990302026, 'wine': 1.7669086660825302, 'fruit': 0.7923477330219887}

# %%
unique_tokens(df, 
              comparison_column = 'reviews', 
              split_column = 'type',
              n_total_corpora = 5,
              n_top_terms = 10)
# Out:
# Unique tokens observed for the label Red Wine:
#
# {'cabernet': 228.6345303314344, 'franc': 90.24400560580965, 'blackberry': 77.02277360173271, 'cassis': 70.79258504268059, 'black': 67.31911708497897, 'blue': 49.35632564657918, 'violet': 44.582533786763626, 'tannin': 43.35402599057205, 'dark': 37.392538474042375, 'chocolate': 36.09925627468468}
#
#
# Unique tokens observed for the label White Wine:
#
# {'pineapple': 15.99576923076923, 'beeswax': 15.808684210526316, 'passion': 15.287518796992481, 'melon': 12.646947368421053, 'flinty': 12.646947368421053, 'lychee': 12.160526315789474, 'grass': 11.813082706766917, 'semillon': 11.674105263157895, 'lime': 10.987904135338345, 'adige': 10.701263157894738}
#
#
# Unique tokens observed for the label Sparkling & Champagne:
#
# {'mousse': 350.18732261116367, 'nv': 309.7626931567329, 'vinous': 123.23532008830023, 'réserve': 80.37086092715232, 'g': 70.80290129296752, 'aperitif': 54.61096960434708, 'pinpoint': 51.666982024597914, 'biscuit': 46.88300220750552, 'appetizer': 37.952906548933036, 'brioche': 37.39477557027226}
#
#
# Unique tokens observed for the label Pink and Rosé:
#
# {'watermelon': 21.733218588640277, 'handroll': 17.74879518072289, 'provence': 15.776706827309237, 'rosé': 13.650810810810812, 'sharply': 13.039931153184167, 'avocado': 12.811160431198479, 'viura': 10.142168674698796, 'cotes': 10.142168674698796, 'cinsault': 9.983697289156627, 'pale': 8.69328743545611}
#
#
# Unique tokens observed for the label Collectible:
#
# {'solera': 250.55769230769232, 'residual': 167.03846153846155, 'sugar': 118.90873533246413, 'tiny': 106.62029459901801, 'touriga': 87.91497975708502, 'caramel': 76.25668896321069, 'sweetness': 45.97388849682428, 'fig': 41.0750315258512, 'september': 34.16695804195804, 'case': 28.966207203201424}
#
#
# Unique tokens observed for the label Green Wine:
#
# {'quince': 156.384, 'apricot': 57.919999999999995, 'honey': 54.954216867469874, 'orange': 13.383311938382542, 'glass': 10.711232876712328, 'peach': 10.31012658227848, 'lemon': 8.696282173498568, 'sweet': 7.6749116607773855, 'finish': 2.375693741138343, 'note': 2.316505840528187}
#
#
# Unique tokens observed for the label Screw Cap:
#
# {'sweet': 3.743643051335359, 'color': 3.514864864864865, 'dry': 1.4564357174854414, 'nan': 1.267909220387263, 'acidity': 1.2240822912464704, 'year': 1.128367532861915, 'fresh': 1.03161652218256, 'aroma': 0.9015363552074037, 'flavor': 0.8028879132940048, 'finish': 0.7834551877105069}
#
#
# Unique tokens observed for the label Boutique:
#
# {'port': 1240.952380952381, 'old': 11.625624553890079, 'great': 6.509792166266986, 'chocolate': 6.14159125188537, 'dark': 4.576058599237407, 'year': 3.4858212948100586, 'hint': 3.4735551290253786, 'long': 3.3565172591447707, 'dry': 2.995402298850575, 'note': 2.4828506097560976}

# %% [markdown]
# Observing the unique terms produced in the OvR analysis does produce an interesting insight that the reviews tend to focus more on the tasting notes of the product. Depending on the predictive application, this dynamic could be useful for informing the final model inputs.
